# %% [markdown]
# # Learning Bokeh

# %% [markdown]
# ## basic plotting

# %%
import numpy as np
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0d82ae2b-75ad-416a-9115-361e24b6328d">Loading BokehJS ...</span>
#     </div>

# %%
stress_v1 = [
    0.0,77.2,154.4,231.7,308.9,328.2,347.5,366.8,386.1,394.4,
    402.7,410.9,419.2,427.5,435.7,444.0,452.3,460.5,468.8]
strain_v1 =[
    0.00000,0.00109,0.00217,0.00326,0.00437,0.00470,0.00514,0.00589,0.00744,0.00860,0.01026,0.01265,
    0.01609,0.02102,0.02806,0.03807,0.05222,0.07214,0.10000]

stress_v2 =[
    0.0,77.3,154.8,232.4,310.2,329.7,349.3,369.0,389.0,397.8,406.8,
    416.1,425.9,436.4,448.0,460.9,475.9,493.8,515.7]
stain_v2 =[
    0.00000,0.00109,0.00217,0.00326,0.00436,0.00469,0.00513,0.00587,
    0.00741,0.00856,0.01021,0.01257,0.01596,0.02080,0.02767,0.03736,0.05091,0.06965,0.09531]

# %%
p = figure(plot_width= 500, plot_height= 400, title="Stress/Strain Curve")
p.line(strain_v1,stress_v1,line_width=2)
p.grid.grid_line_alpha = 0
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="f5098b76-4cfd-4e85-84e6-10a60d8cad2a"></div>
# </div>
