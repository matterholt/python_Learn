# %%
import pandas as pd

# %% [markdown]
# # Quickest way to bring in the data
#             Pretty ruff outcome-- improvement to the dataset is flowed

# %%
broken_df = pd.read_csv('data/data_Cycle.csv')

# %%
broken_df[:3]
# Out:
#   Date;Berri 1;Brébeuf (données non disponibles);Côte-Sainte-Catherine;Maisonneuve 1;Maisonneuve 2;du Parc;Pierre-Dupuy;Rachel1;St-Urbain (données non disponibles)
# 0                   01/01/2012;35;;0;38;51;26;10;16;
# 1                   02/01/2012;83;;1;68;153;53;6;43;
# 2                 03/01/2012;135;;2;104;248;89;3;58;

# %% [markdown]
# # Fixing the dataframe
#         Setting some parameters or setting to help construct the

# %%
fixed_df = pd.read_csv('data/data_Cycle.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
fixed_df [:4]
# Out:
#             Berri 1  BrÃ©beuf (donnÃ©es non disponibles)  \
# Date
# 2012-01-01       35                                  NaN
# 2012-01-02       83                                  NaN
# 2012-01-03      135                                  NaN
# 2012-01-04      144                                  NaN
#
#             CÃ´te-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  \
# Date
# 2012-01-01                       0             38             51       26
# 2012-01-02                       1             68            153       53
# 2012-01-03                       2            104            248       89
# 2012-01-04                       1            116            318      111
#
#             Pierre-Dupuy  Rachel1  St-Urbain (donnÃ©es non disponibles)
# Date
# 2012-01-01            10       16                                   NaN
# 2012-01-02             6       43                                   NaN
# ...

# %%
fixed_df['Berri 1']
# Out:
# Date
# 2012-01-01      35
# 2012-01-02      83
# 2012-01-03     135
# 2012-01-04     144
# 2012-01-05     197
# 2012-01-06     146
# 2012-01-07      98
# 2012-01-08      95
# 2012-01-09     244
# 2012-01-10     397
# 2012-01-11     273
# 2012-01-12     157
# 2012-01-13      75
# 2012-01-14      32
# 2012-01-15      54
# 2012-01-16     168
# 2012-01-17     155
# 2012-01-18     139
# 2012-01-19     191
# 2012-01-20     161
# 2012-01-21      53
# 2012-01-22      71
# 2012-01-23     210
# 2012-01-24     299
# 2012-01-25     334
# 2012-01-26     306
# 2012-01-27      91
# 2012-01-28      80
# 2012-01-29      87
# 2012-01-30     219
#               ...
# 2012-10-07    1580
# 2012-10-08    1854
# 2012-10-09    4787
# 2012-10-10    3115
# 2012-10-11    3746
# 2012-10-12    3169
# 2012-10-13    1783
# 2012-10-14     587
# 2012-10-15    3292
# 2012-10-16    3739
# 2012-10-17    4098
# 2012-10-18    4671
# 2012-10-19    1313
# 2012-10-20    2011
# 2012-10-21    1277
# 2012-10-22    3650
# ...

# %% [markdown]
# # 1.3 Plotting a column

# %%
fixed_df['Berri 1'].plot()

# %%
fixed_df.plot(figsize=(15, 10))
